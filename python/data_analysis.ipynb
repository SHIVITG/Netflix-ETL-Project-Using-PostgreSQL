# %% [markdown]
# # Data Analysis Notebook
#
# This notebook demonstrates how to load the integrated `netflix_final` table from PostgreSQL into pandas and perform a quick visualization.

# %%
import pandas as pd
from sqlalchemy import create_engine
from db_connection import get_engine

# create the engine using environment variables or default credentials
engine = get_engine()

# read the final table into a DataFrame", 
, 
, 
, 
]}, {
: 
, 
: null, 
: {}, 
: [], 
: [
, 
, 
, 
]}], 
: {
: {
: 
3
, 
: 
, 
: 
}, 
: {
: 
}}, 
: 4, 
: 5}
